# %% [markdown]
# <a href="https://colab.research.google.com/github/ReDI-School/hh-dcp-intro-to-computer-science/blob/main/content_2022/6.%20Python%20Libraries/6.%20Intro_to_Python_Libraries.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 10 May - Python Libraries
#
#
# ![python gif](https://media.giphy.com/media/KAq5w47R9rmTuvWOWa/giphy.gif)
#
# ## Pre Requisites
#
# Basic fundamentals of Python
#
# ---
#
#
# ##  Libraries
#
# "A library is a collection of materials, books or media that are accessible for use. A library provides physical (hard copies) or digital access (soft copies) materials, and may be a physical location or a virtual space, or both." - *Wikipedia*
#
# Python libraries is a collection of pre-written code functions that can be imported and used my anyone. Libraries are ready made solutions to common programming tasks. In the end it's just code that you do not need to write yourself, which you can use to make your life as a programmer a little bit easier.

# %% [markdown]
# ### Similar Terms to Libraries
#
# **Script** - is a python file containing sequence of python statements.
#
# **Module** - is a file that can be imported into scripts and other modules. It containes python codes that defines functions, classes and variables.
#
# **Package** - is a collection of one or more python modules. Package is a way to organised modules.
#
# **Library** - is a collection of pre-written code that provides a specific funtionality.

# %% [markdown]
# ### Example
#
# ##### Writing your function yourself

# %%
def multiply(first_number: float, second_number: float) -> float:
    
    # This function multiply two numbers and return the result
    
    result = first_number * second_number
    
    return result

# %%
# call self build function 
a = 5
b = 10
my_function_result = multiply(a, b)

print(f"Using self made function \n result of {a} x {b} = {my_function_result}")
# Out:
# Using self made function
#  result of 5 x 10 = 50

# %% [markdown]
# ##### Using numpy Library

# %%
# import libraries
import numpy as np 

library_result = np.multiply(a, b)

print(f"Using numpy library \n result of {a} x {b} = {library_result}")
# Out:
# Using numpy library
#  result of 5 x 10 = 50

# %% [markdown]
# ### Libraries in Python
#
# Before you can use a library in python, you need to install
#
# ```pip install numpy```
#
# Note: You don't need to install numpy again because it is already installed in your environment.
#
# ![Top most used libraries in python](Top-10-Python-Libraries.png)
#
# image source - https://datarundown.com/python-top10-libraries/

# %%
#### NumPy

NumPy is an open source project aiming to enable numerical computing with Python. [https://numpy.org](https://numpy.org)

#### working with arrays

NumPy supports a variety of use cases when working with numeric or tabular data, which come most handy in data processing or datascience. You can use the following website as a reference:
[https://numpy.org/devdocs/user/quickstart.html](https://numpy.org/devdocs/user/quickstart.html)

# %%
import numpy as np

# create a two dimensional array with some numbers
dim2array = np.array([
    [10, 11, 12, 13, 14, 15],
    [20, 21, 22, 23, 24, 25], 
    [30, 31, 32, 33, 34, 35],
    [40, 41, 42, 43, 44, 45]
])

# %%
# to see the size of the array dimensions (4 rows with 6 columns)
print(dim2array.shape)
# Out:
# (4, 6)

# %%
# element wise operations
print("add '3' to each element: {}".format(
    (dim2array[0]+3))
)
# Out:
# add '3' to each element: [13 14 15 16 17 18]

# %%
# you can transform the shape of arrays by providing the new dimensions
dim1array = dim2array.reshape(24)
print(f"one dimensional: {dim1array}")
print(f"add all elements: {dim1array.sum()}")
# Out:
# one dimensional: [10 11 12 13 14 15 20 21 22 23 24 25 30 31 32 33 34 35 40 41 42 43 44 45]
# add all elements: 660

# %%
print(f"Maximum number {dim1array.max()}")
# Out:
# Maximum number 45

# %% [markdown]
# ### pandas
#
# pandas is a fast, powerful, flexible and easy to use open source data analysis and manipulation tool, built on top of the Python programming language. [https://pandas.pydata.org/](https://pandas.pydata.org/)
#
# #### loading and storing CSV data from/to files

# %% [markdown]
# Pandas is a rather large library with many features, so we will take a look at a data visualization show case to get a grasp of Pandas capabilities.
# Let's take for example some RKI Data with corona cases per 'Bundesland' from https://www.rki.de/DE/Content/InfAZ/N/Neuartiges_Coronavirus/Daten/Inzidenz-Tabellen.html?nn=13490888
# You find the data in the 'fallzahlen.txt' file.

# %%
import pandas as pd

fallzahlen = pd.read_csv("fallzahlen.txt", sep='\t')
fallzahlen
# Out:
#                 bundesland  06.05.20  07.05.20  08.05.20  09.05.20  10.05.20  \
# 0        Baden-Württemberg       908       779       665       706       772
# 1                   Bayern      1318      1246      1182      1223      1148
# 2                   Berlin       276       265       272       280       269
# 3              Brandenburg       125       116       117       131       118
# 4                   Bremen       119       126       140       155       170
# 5                  Hamburg        95        85        86        89        80
# 6                   Hessen       447       420       424       415       456
# 7   Mecklenburg-Vorpommern        23        23        22        22        24
# 8            Niedersachsen       361       350       351       430       417
# 9      Nordrhein-Westfalen      1465      1498      1379      1448      1449
# 10         Rheinland-Pfalz       208       176       157       159       149
# 11                Saarland        94        87        64        55        52
# 12                 Sachsen       149       162       155       170       163
# 13          Sachsen-Anhalt        54        50        52        60        58
# 14      Schleswig-Holstein       140       142       149       174       202
# 15               Thüringen       198       180       179       186       188
# 16                  Gesamt      5980      5705      5394      5703      5715
#
#     11.05.20  12.05.20  13.05.20  14.05.20  ...  01.09.21  02.09.21  03.09.21  \
# 0        760       774       744       765  ...      8694      9072      9287
# 1       1151      1198      1194      1115  ...      9174      8494      9692
# 2        248       198       170       156  ...      2951      3049      3071
# 3        118       105        72        50  ...       716       715       774
# 4        165       151       160       134  ...       643       661       687
# 5         85        83        74        57  ...      1430      1407      1463
# 6        444       442       407       387  ...      5387      5990      6525
# 7         26        23        23        23  ...       522       547       557
# 8        429       376       305       310  ...      4816      4867      5174
# 9       1496      1535      1515      1395  ...     21568     21509     21323
# 10       171       185       160       152  ...      3071      3399      3718
# 11        50        41        35        30  ...       874       894       908
# 12       182       209       164       171  ...       793       920      1020
# 13        57        56        39        37  ...       368       413       473
# 14       171       159       128       123  ...      1387      1440      1438
# 15       216       195       184       170  ...       526       565       577
# 16      5769      5730      5374      5075  ...     62920     63942     66687
#
#     04.09.21  05.09.21  06.09.21  07.09.21  08.09.21  09.09.21  10.09.21
# 0       9686     10087     10345     10116     10100     10286     10356
# 1       9858      9971     10169     10182     10185     10514     10684
# 2       3034      3057      3022      3219      2967      3039      3104
# 3        836       917       945       921       948      1016      1038
# 4        717       747       790       785       800       831       846
# 5       1439      1485      1502      1478      1462      1487      1446
# 6       6931      7329      7357      7243      7152      6956      6909
# 7        538       557       580       556       587       618       638
# 8       4742      5699      5804      5702      5728      5999      6126
# 9      20905     20600     20609     20390     19607     19432     19159
# 10      3863      3905      4109      4245      4223      4114      4138
# 11       915       939       960       948       878       892       834
# 12      1079      1178      1230      1190      1305      1451      1535
# 13       494       500       509       552       551       584       561
# 14      1440      1495      1470      1478      1429      1374      1364
# 15       612       645       662       696       813       864       934
# 16     67089     69111     70063     69701     68735     69457     69672
#
# [17 rows x 494 columns]

# %%
# to parse some data with non standard formatting: (we use transpose to change rows with columns)
fallzahlen_transpose = pd.read_csv("fallzahlen.txt", sep='\t', index_col=0).transpose()

# Pandas will try to guess the data type of the columns
# fallzahlen = fallzahlen.apply(pd.to_numeric, errors='ignore')

# to display the first 5 rows of our data:
fallzahlen_transpose.head(10)
# Out:
# bundesland  Baden-Württemberg  Bayern  Berlin  Brandenburg  Bremen  Hamburg  \
# 06.05.20                  908    1318     276          125     119       95
# 07.05.20                  779    1246     265          116     126       85
# 08.05.20                  665    1182     272          117     140       86
# 09.05.20                  706    1223     280          131     155       89
# 10.05.20                  772    1148     269          118     170       80
# 11.05.20                  760    1151     248          118     165       85
# 12.05.20                  774    1198     198          105     151       83
# 13.05.20                  744    1194     170           72     160       74
# 14.05.20                  765    1115     156           50     134       57
# 15.05.20                  725    1022     154           55     130       47
#
# bundesland  Hessen  Mecklenburg-Vorpommern  Niedersachsen  \
# 06.05.20       447                      23            361
# 07.05.20       420                      23            350
# 08.05.20       424                      22            351
# 09.05.20       415                      22            430
# 10.05.20       456                      24            417
# 11.05.20       444                      26            429
# 12.05.20       442                      23            376
# 13.05.20       407                      23            305
# 14.05.20       387                      23            310
# 15.05.20       350                      18            296
#
# bundesland  Nordrhein-Westfalen  Rheinland-Pfalz  Saarland  Sachsen  \
# 06.05.20                   1465              208        94      149
# 07.05.20                   1498              176        87      162
# 08.05.20                   1379              157        64      155
# 09.05.20                   1448              159        55      170
# 10.05.20                   1449              149        52      163
# 11.05.20                   1496              171        50      182
# 12.05.20                   1535              185        41      209
# 13.05.20                   1515              160        35      164
# 14.05.20                   1395              152        30      171
# 15.05.20                   1303              148        29      165
#
# bundesland  Sachsen-Anhalt  Schleswig-Holstein  Thüringen  Gesamt
# 06.05.20                54                 140        198    5980
# 07.05.20                50                 142        180    5705
# 08.05.20                52                 149        179    5394
# 09.05.20                60                 174        186    5703
# 10.05.20                58                 202        188    5715
# 11.05.20                57                 171        216    5769
# 12.05.20                56                 159        195    5730
# 13.05.20                39                 128        184    5374
# 14.05.20                37                 123        170    5075
# 15.05.20                36                  95        154    4727

# %%
# display details of the DataFrame
fallzahlen_transpose.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 493 entries, 06.05.20 to 10.09.21
# Data columns (total 17 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Baden-Württemberg       493 non-null    int64
#  1   Bayern                  493 non-null    int64
#  2   Berlin                  493 non-null    int64
#  3   Brandenburg             493 non-null    int64
#  4   Bremen                  493 non-null    int64
#  5   Hamburg                 493 non-null    int64
#  6   Hessen                  493 non-null    int64
#  7   Mecklenburg-Vorpommern  493 non-null    int64
#  8   Niedersachsen           493 non-null    int64
#  9   Nordrhein-Westfalen     493 non-null    int64
#  10  Rheinland-Pfalz         493 non-null    int64
#  11  Saarland                493 non-null    int64
#  12  Sachsen                 493 non-null    int64
#  13  Sachsen-Anhalt          493 non-null    int64
#  14  Schleswig-Holstein      493 non-null    int64
#  15  Thüringen               493 non-null    int64
#  16  Gesamt                  493 non-null    int64
# dtypes: int64(17)
# memory usage: 69.3+ KB

# %%
fallzahlen_transpose[["Hamburg"]]
# Out:
# bundesland  Hamburg
# 06.05.20         95
# 07.05.20         85
# 08.05.20         86
# 09.05.20         89
# 10.05.20         80
# ...             ...
# 06.09.21       1502
# 07.09.21       1478
# 08.09.21       1462
# 09.09.21       1487
# 10.09.21       1446
#
# [493 rows x 1 columns]

# %%
fallzahlen_transpose[["Hamburg"]].plot(rot=45,
                                    figsize=(25, 15),
                                    fontsize=20).legend(fontsize=20)

# %%
fallzahlen_transpose[["Hamburg","Berlin","Bayern","Nordrhein-Westfalen"]]
# Out:
# bundesland  Hamburg  Berlin  Bayern  Nordrhein-Westfalen
# 06.05.20         95     276    1318                 1465
# 07.05.20         85     265    1246                 1498
# 08.05.20         86     272    1182                 1379
# 09.05.20         89     280    1223                 1448
# 10.05.20         80     269    1148                 1449
# ...             ...     ...     ...                  ...
# 06.09.21       1502    3022   10169                20609
# 07.09.21       1478    3219   10182                20390
# 08.09.21       1462    2967   10185                19607
# 09.09.21       1487    3039   10514                19432
# 10.09.21       1446    3104   10684                19159
#
# [493 rows x 4 columns]

# %%
# plot as a line diagram
fallzahlen_transpose[["Hamburg","Berlin","Bayern","Nordrhein-Westfalen"]].plot(rot=45,
                                                                               figsize=(25, 15),
                                                                               fontsize=20).legend(fontsize=20)

# %%
# load 'Bundesland einwohner dataset'
einwohner = pd.read_csv("Bundesland_Einwohner_2020")
einwohner
# Out:
#          Bundesland;Einwohner_2020
# 0     Nordrhein-Westfalen;17925570
# 1                  Bayern;13140183
# 2       Baden-Württemberg;11103043
# 3            Niedersachsen;8003421
# 4                   Hessen;6293154
# 5          Rheinland-Pfalz;4098391
# 6                  Sachsen;4056941
# 7                   Berlin;3664088
# 8       Schleswig-Holstein;2910875
# 9              Brandenburg;2531071
# 10          Sachsen-Anhalt;2180684
# 11               Thüringen;2120237
# 12                 Hamburg;1852478
# 13  Mecklenburg-Vorpommern;1610774
# 14                 Saarland;983991
# 15                   Bremen;680130

# %%
einwohner = pd.read_csv("Bundesland_Einwohner_2020", sep=';')
einwohner
# Out:
#                 Bundesland  Einwohner_2020
# 0      Nordrhein-Westfalen        17925570
# 1                   Bayern        13140183
# 2        Baden-Württemberg        11103043
# 3            Niedersachsen         8003421
# 4                   Hessen         6293154
# 5          Rheinland-Pfalz         4098391
# 6                  Sachsen         4056941
# 7                   Berlin         3664088
# 8       Schleswig-Holstein         2910875
# 9              Brandenburg         2531071
# 10          Sachsen-Anhalt         2180684
# 11               Thüringen         2120237
# 12                 Hamburg         1852478
# 13  Mecklenburg-Vorpommern         1610774
# 14                Saarland          983991
# 15                  Bremen          680130

# %%
# load the file into the DataFrame 'einwohner'
einwohner_transpose= pd.read_csv("Bundesland_Einwohner_2020", sep=';', index_col=0).transpose()
einwohner_transpose
# Out:
# Bundesland      Nordrhein-Westfalen    Bayern  Baden-Württemberg  \
# Einwohner_2020             17925570  13140183           11103043
#
# Bundesland      Niedersachsen   Hessen  Rheinland-Pfalz  Sachsen   Berlin  \
# Einwohner_2020        8003421  6293154          4098391  4056941  3664088
#
# Bundesland      Schleswig-Holstein  Brandenburg  Sachsen-Anhalt  Thüringen  \
# Einwohner_2020             2910875      2531071         2180684    2120237
#
# Bundesland      Hamburg  Mecklenburg-Vorpommern  Saarland  Bremen
# Einwohner_2020  1852478                 1610774    983991  680130

# %%
# we can access the numbers like this:
#einwohner [1][0]
einwohner_transpose["Bayern"][0] #firt one is column second is row
# Out:
# 13140183

# %% [markdown]
# To be able to compare the numbers, we will calculate the number of infections per 100.000 citizens. e.g.
#
# Bayern: 1318 cases
#
# Bayern: 13140183 citizens
#
#       1318 / (13140183/100000) = 10.03030170888792
#
# Next we need the number of citizens per Bundesland from Wikipedia https://de.wikipedia.org/wiki/Liste_der_deutschen_Bundesl%C3%A4nder_nach_Bev%C3%B6lkerung
# which are stored in the file "Bundesland_Einwohner_2020":

# %%
# we copy the dataframe because we change the contents below
normalized = fallzahlen_transpose.copy()

# %%
einwohner_transpose.columns
# Out:
# Index(['Nordrhein-Westfalen', 'Bayern', 'Baden-Württemberg', 'Niedersachsen',
#        'Hessen', 'Rheinland-Pfalz', 'Sachsen', 'Berlin', 'Schleswig-Holstein',
#        'Brandenburg', 'Sachsen-Anhalt', 'Thüringen', 'Hamburg',
#        'Mecklenburg-Vorpommern', 'Saarland', 'Bremen'],
#       dtype='object', name='Bundesland')

# %%
list(einwohner_transpose.columns)
# Out:
# ['Nordrhein-Westfalen',
#  'Bayern',
#  'Baden-Württemberg',
#  'Niedersachsen',
#  'Hessen',
#  'Rheinland-Pfalz',
#  'Sachsen',
#  'Berlin',
#  'Schleswig-Holstein',
#  'Brandenburg',
#  'Sachsen-Anhalt',
#  'Thüringen',
#  'Hamburg',
#  'Mecklenburg-Vorpommern',
#  'Saarland',
#  'Bremen']

# %%
# now we add new Columns to the DataFrame with the numbers from the formula
for title in einwohner_transpose.columns:
  normalized[title]=normalized[title]/(einwohner_transpose[title][0]/100000)

# %%
normalized
# Out:
# bundesland  Baden-Württemberg     Bayern     Berlin  Brandenburg      Bremen  \
# 06.05.20             8.177938  10.030302   7.532570     4.938621   17.496655
# 07.05.20             7.016095   9.482364   7.232359     4.583040   18.525870
# 08.05.20             5.989349   8.995309   7.423402     4.622549   20.584300
# 09.05.20             6.358617   9.307329   7.641738     5.175675   22.789761
# 10.05.20             6.953049   8.736560   7.341527     4.662058   24.995222
# ...                       ...        ...        ...          ...         ...
# 06.09.21            93.172655  77.388572  82.476185    37.335974  116.154265
# 07.09.21            91.110158  77.487505  87.852693    36.387758  115.419111
# 08.09.21            90.966053  77.510336  80.975129    37.454500  117.624572
# 09.09.21            92.641270  80.014106  82.940148    40.141110  122.182524
# 10.09.21            93.271727  81.307848  84.714123    41.010307  124.387985
#
# bundesland    Hamburg      Hessen  Mecklenburg-Vorpommern  Niedersachsen  \
# 06.05.20     5.128266    7.102957                1.427885       4.510571
# 07.05.20     4.588449    6.673919                1.427885       4.373130
# 08.05.20     4.642430    6.737480                1.365803       4.385625
# 09.05.20     4.804376    6.594468                1.365803       5.372702
# 10.05.20     4.318540    7.245969                1.489967       5.210272
# ...               ...         ...                     ...            ...
# 06.09.21    81.080585  116.904814               36.007534      72.518989
# 07.09.21    79.785023  115.093322               34.517567      71.244534
# 08.09.21    78.921315  113.647306               36.442108      71.569395
# 09.09.21    80.270859  110.532811               38.366649      74.955447
# 10.09.21    78.057607  109.785967               39.608288      76.542269
#
# bundesland  Nordrhein-Westfalen  Rheinland-Pfalz   Saarland    Sachsen  \
# 06.05.20               8.172683         5.075162   9.552933   3.672718
# 07.05.20               8.356777         4.294368   8.841544   3.993156
# 08.05.20               7.692921         3.830772   6.504125   3.820613
# 09.05.20               8.077846         3.879571   5.589482   4.190349
# 10.05.20               8.083425         3.635573   5.284601   4.017806
# ...                         ...              ...        ...        ...
# 06.09.21             114.969845       100.258858  97.561868  30.318410
# 07.09.21             113.748126       103.577233  96.342345  29.332445
# 08.09.21             109.380064       103.040437  89.228458  32.167093
# 09.09.21             108.403805       100.380857  90.651236  35.765864
# 10.09.21             106.880841       100.966452  84.756873  37.836390
#
# bundesland  Sachsen-Anhalt  Schleswig-Holstein  Thüringen  Gesamt
# 06.05.20          2.476287            4.809550   9.338579    5980
# 07.05.20          2.292859            4.878258   8.489617    5705
# 08.05.20          2.384573            5.118736   8.442452    5394
# 09.05.20          2.751430            5.977584   8.772604    5703
# 10.05.20          2.659716            6.939494   8.866933    5715
# ...                    ...                 ...        ...     ...
# 06.09.21         23.341300           50.500279  31.222925   70063
# 07.09.21         25.313159           50.775111  32.826519   69701
# 08.09.21         25.267301           49.091768  38.344770   68735
# 09.09.21         26.780588           47.202302  40.750161   69457
# 10.09.21         25.725873           46.858762  44.051679   69672
#
# [493 rows x 17 columns]

# %%
# "normalized" now holds the number of corona cases for each date and every Bundesland per 100.000 citizens
normalized.head()
# Out:
# bundesland  Baden-Württemberg     Bayern    Berlin  Brandenburg     Bremen  \
# 06.05.20             8.177938  10.030302  7.532570     4.938621  17.496655
# 07.05.20             7.016095   9.482364  7.232359     4.583040  18.525870
# 08.05.20             5.989349   8.995309  7.423402     4.622549  20.584300
# 09.05.20             6.358617   9.307329  7.641738     5.175675  22.789761
# 10.05.20             6.953049   8.736560  7.341527     4.662058  24.995222
#
# bundesland   Hamburg    Hessen  Mecklenburg-Vorpommern  Niedersachsen  \
# 06.05.20    5.128266  7.102957                1.427885       4.510571
# 07.05.20    4.588449  6.673919                1.427885       4.373130
# 08.05.20    4.642430  6.737480                1.365803       4.385625
# 09.05.20    4.804376  6.594468                1.365803       5.372702
# 10.05.20    4.318540  7.245969                1.489967       5.210272
#
# bundesland  Nordrhein-Westfalen  Rheinland-Pfalz  Saarland   Sachsen  \
# 06.05.20               8.172683         5.075162  9.552933  3.672718
# 07.05.20               8.356777         4.294368  8.841544  3.993156
# 08.05.20               7.692921         3.830772  6.504125  3.820613
# 09.05.20               8.077846         3.879571  5.589482  4.190349
# 10.05.20               8.083425         3.635573  5.284601  4.017806
#
# bundesland  Sachsen-Anhalt  Schleswig-Holstein  Thüringen  Gesamt
# 06.05.20          2.476287            4.809550   9.338579    5980
# 07.05.20          2.292859            4.878258   8.489617    5705
# 08.05.20          2.384573            5.118736   8.442452    5394
# 09.05.20          2.751430            5.977584   8.772604    5703
# 10.05.20          2.659716            6.939494   8.866933    5715

# %%
list(normalized.columns)
# Out:
# ['Baden-Württemberg',
#  'Bayern',
#  'Berlin',
#  'Brandenburg',
#  'Bremen',
#  'Hamburg',
#  'Hessen',
#  'Mecklenburg-Vorpommern',
#  'Niedersachsen',
#  'Nordrhein-Westfalen',
#  'Rheinland-Pfalz',
#  'Saarland',
#  'Sachsen',
#  'Sachsen-Anhalt',
#  'Schleswig-Holstein',
#  'Thüringen',
#  'Gesamt']

# %%
# remove a column from a dataset 
normalized=normalized.drop(['Gesamt'], axis=1)

list(normalized.columns)
# Out:
# ['Baden-Württemberg',
#  'Bayern',
#  'Berlin',
#  'Brandenburg',
#  'Bremen',
#  'Hamburg',
#  'Hessen',
#  'Mecklenburg-Vorpommern',
#  'Niedersachsen',
#  'Nordrhein-Westfalen',
#  'Rheinland-Pfalz',
#  'Saarland',
#  'Sachsen',
#  'Sachsen-Anhalt',
#  'Schleswig-Holstein',
#  'Thüringen']

# %%
# save a pandas dataframe as csv file
saving_path = "corona.csv"
normalized.to_csv(saving_path, index=False)

# %%
# now we plot all columns except "Gesamt" 

# normalized.plot(rot=45, figsize=(22, 16))

# %%
#pandasstart
import pandas as pd
import numpy as np

#%% Series
my_series = pd.Series(np.arange(3), index=['a', 'b', 'c'])
# %%
# my_series[0]  # access via index
my_series['a']  # access via label

#%% create dataframe
# from dict
my_dict = {'name': ['Bob', 'Stuart', 'Kevin'], 'grades': [1, 2, 3]}
df = pd.DataFrame(my_dict)
df
# Out:
# Index(['name', 'grades'], dtype='object')

# %%
# %%
from numpy import array
column_names=["height", "width"]
df = pd.DataFrame(np.random.rand(2, 2), columns=column_names)
df.columns
df

# now set/change column names after creation
#df = pd.DataFrame(np.random.rand(2, 2))
df.columns = ['H', "width"]
df
len(df)
# Out:
# 2

# %%
#eda
# %% [markdown]
# Import **pandas** as the required package for working with dataframes.

# %%
import pandas as pd

# A dataframe is a multi-dimensional table with rows and columns.

# %% Creating a Dataframe
# Usually you import a dataframe from a file, a SQL server, or a web-resource. But here I will show you how to create a dataframe from scratch.
# 
# You can create a dataframe based on lists, tuples, arrays. Here we develop it based on a dictionary.

# %%
my_dictionary = {
    'A': [1,2,3],
    'B': [4,5,6],
    'C': [7,8,9]
}
df = pd.DataFrame(data=my_dictionary)
df

# A dataframe has columns (here: A, B, C), and rows. The index is creating and starts with 0.
# Out:
#    A  B  C
# 0  1  4  7
# 1  2  5  8
# 2  3  6  9

# %%
#filename = 'df.csv' 
df.to_csv("df.csv", index=False)

# %%
corona=pd.read_csv("./corona.csv")
corona.head()
# Out:
#    Baden-Württemberg     Bayern    Berlin  Brandenburg     Bremen   Hamburg  \
# 0           8.177938  10.030302  7.532570     4.938621  17.496655  5.128266
# 1           7.016095   9.482364  7.232359     4.583040  18.525870  4.588449
# 2           5.989349   8.995309  7.423402     4.622549  20.584300  4.642430
# 3           6.358617   9.307329  7.641738     5.175675  22.789761  4.804376
# 4           6.953049   8.736560  7.341527     4.662058  24.995222  4.318540
#
#      Hessen  Mecklenburg-Vorpommern  Niedersachsen  Nordrhein-Westfalen  \
# 0  7.102957                1.427885       4.510571             8.172683
# 1  6.673919                1.427885       4.373130             8.356777
# 2  6.737480                1.365803       4.385625             7.692921
# 3  6.594468                1.365803       5.372702             8.077846
# 4  7.245969                1.489967       5.210272             8.083425
#
#    Rheinland-Pfalz  Saarland   Sachsen  Sachsen-Anhalt  Schleswig-Holstein  \
# 0         5.075162  9.552933  3.672718        2.476287            4.809550
# 1         4.294368  8.841544  3.993156        2.292859            4.878258
# 2         3.830772  6.504125  3.820613        2.384573            5.118736
# 3         3.879571  5.589482  4.190349        2.751430            5.977584
# 4         3.635573  5.284601  4.017806        2.659716            6.939494
#
#    Thüringen
# 0   9.338579
# 1   8.489617
# 2   8.442452
# 3   8.772604
# 4   8.866933

# %%
corona.describe()
# Out:
#        Baden-Württemberg      Bayern      Berlin  Brandenburg      Bremen  \
# count         493.000000  493.000000  493.000000   493.000000  493.000000
# mean           60.555005   65.813159   67.197858    52.035713   60.709072
# std            59.490707   65.017874   62.561034    60.630723   54.171876
# min             0.981713    1.529659    3.002111     0.592635    1.323276
# 25%             7.907742    9.086631   10.916768     2.568083   11.468396
# 50%            42.114581   37.495673   53.683208    22.796674   52.048873
# 75%           112.392612  120.477774  112.961261    90.949641   97.187302
# max           207.753856  217.584489  224.421466   257.558954  225.986209
#
#           Hamburg      Hessen  Mecklenburg-Vorpommern  Niedersachsen  \
# count  493.000000  493.000000              493.000000     493.000000
# mean    51.653415   66.250878               38.701110      43.590006
# std     45.094480   61.743852               42.520394      39.053763
# min      0.323890    1.700260                0.000000       0.912110
# 25%      8.906988    9.804305                1.800377       5.347713
# 50%     40.054457   46.717433               19.245406      27.875580
# 75%     87.018577  123.546953               67.110594      81.665078
# max    154.927616  208.941335              157.688167     123.272286
#
#        Nordrhein-Westfalen  Rheinland-Pfalz    Saarland     Sachsen  \
# count           493.000000       493.000000  493.000000  493.000000
# mean             66.750240        52.770722   57.384593   85.485676
# std              60.005126        50.563401   54.164713  110.203732
# min               3.090557         0.805194    0.304881    0.271140
# 25%               9.411137         7.319946    5.995990    3.253683
# 50%              54.190745        33.208154   44.715856   21.765167
# 75%             122.277841        99.917260  105.183889  150.458190
# max             192.730273       170.261939  188.314731  446.025712
#
#        Sachsen-Anhalt  Schleswig-Holstein   Thüringen
# count      493.000000          493.000000  493.000000
# mean        57.666463           33.785802   82.409269
# std         68.464883           30.270920   96.665499
# min          0.321000            0.240478    0.660304
# 25%          2.292859            4.191180    3.961821
# 50%         14.995295           30.334521   21.884346
# 75%        106.755495           54.622751  149.936068
# max        244.693867          109.898226  329.915948

# %%
#len(corona)
corona.shape
# Out:
# (493, 16)

# %%
# # Import and Export of Dataframes

# You can export a dataframe into different formats like Excel, JSON, ... Here I export it to a CSV file.

# %%
filename = 'df.csv' 
df.to_csv(filename, index=False)

# Similarly the dataframe can be imported with **pandas**. There are many different read-functions to import from different formats.

# %%
df = pd.read_csv(filename)

# # Exploratory Data Analysis

# %% [markdown]
# You can explore the data with *head()* to see the first observations. If you are interested in the last observations go with *tail()*. The argument refers to the number of observations to be shown.

# %%
df.head(2)

# %% [markdown]
# Statistical properties are shown with the *describe()* method.

# %%
df.describe()

# %% [markdown]
# A general summary on the dataframe is provided by *info()* method.

# %%
df.info()

# %% [markdown]
# Often you are interested in getting the number of rows and columns. You can get this with the shape property.

# %%
df.shape

# %% [markdown]
# The column-names are stored in the property *columns*.

# %%
df.columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   A       3 non-null      int64
#  1   B       3 non-null      int64
#  2   C       3 non-null      int64
# dtypes: int64(3)
# memory usage: 200.0 bytes
# Index(['A', 'B', 'C'], dtype='object')

# %%
df
# Out:
#    A  B  C
# 0  1  4  7
# 1  2  5  8
# 2  3  6  9

# %%
df["D"]=[10,11,12]
df["E"]=list(range(13,16))
df["F"]=["hello", "nesli", 3]
df.drop('F', axis=1, inplace=True)
#df.drop(1, axis=0, inplace=True)
df
my_func = lambda x: x + 2
df['G'] = df['A'].apply(my_func)
df
# Out:
#    A  B  C   D   E  G
# 0  1  4  7  10  13  3
# 1  2  5  8  11  14  4
# 2  3  6  9  12  15  5

# %%
#modify
# %% [markdown]
# Import **pandas** as the required package for working with dataframes.

# %%
import pandas as pd

# A dataframe is a multi-dimensional table with rows and columns.

# %% Creating a Dataframe
# Usually you import a dataframe from a file, a SQL server, or a web-resource. But here I will show you how to create a dataframe from scratch.
# 
# You can create a dataframe based on lists, tuples, arrays. Here we develop it based on a dictionary.

# %%
data = {
    'A': [1,2,3],
    'B': [4,5,6],
    'C': [7,8,9]
}
df = pd.DataFrame(data=data)
df

# A dataframe has columns (here: A, B, C), and rows. The index is creating and starts with 0.

# # Import and Export of Dataframes

# You can export a dataframe into different formats like Excel, JSON, ... Here I export it to a CSV file.

# # Adding/Modifying Columns

# %%
df['D'] = list(range(10,13))
df

# %% [markdown]
# # Delete Rows or Columns

# %% [markdown]
# If you want to delete a column use method *drop()* and specify the column name. The argument axis needs to be 1 for columns. With inplace set to true the dataframe is directly modified.

# %%
df.drop('C', axis=1, inplace=True)
df

# %% [markdown]
# Similarly you can delete rows by specifying the index of the row, the axis is 0 for rows and inplace is set to true to change the dataframe directly.

# %%
df.drop(1, axis=0, inplace=True)
df

# %% [markdown]
# # Apply a lambda function to a column

# %% [markdown]
# You can also apply a specific function to a column.

    

# %%


# %% [markdown]
# # Reshape your dataframe structure

# %% [markdown]
# You can reshape your dataframe structure from wide data to tidy data and vice versa. We are starting with wide-data.

# %%
a=[2,3,4]
for num in a:
    num+=2
    print(num)
# Out:
# 4
# 5
# 6

# %%
#filtering #dataneeded
#%% packages
import pandas as pd

#%%
# source: https://perso.telecom-paristech.fr/eagan/class/igr204/datasets
file_path = './factbook.csv'
df = pd.read_csv(file_path, sep=';', skiprows=[1])

df.tail(10)
# Out:
#                Country  Area(sq km)  Birth rate(births/1000 population)  \
# 253          Venezuela       912050                               18.91
# 254            Vietnam       329560                               17.07
# 255     Virgin Islands          352                               14.20
# 256        Wake Island            7                                 NaN
# 257  Wallis and Futuna          274                                 NaN
# 258          West Bank         5860                               32.37
# 259     Western Sahara       266000                                 NaN
# 260              Yemen       527970                               43.07
# 261             Zambia       752614                               41.38
# 262           Zimbabwe       390580                               29.74
#
#      Current account balance  Death rate(deaths/1000 population)  \
# 253             1.459000e+10                                4.90
# 254            -2.061000e+09                                6.20
# 255                      NaN                                6.26
# 256                      NaN                                 NaN
# 257                      NaN                                 NaN
# 258                      NaN                                3.99
# 259                      NaN                                 NaN
# 260             3.699000e+08                                8.53
# 261            -1.814000e+08                               20.23
# 262            -2.303000e+08                               24.66
#
#      Debt - external  Electricity - consumption(kWh)  \
# 253     3.329000e+10                    8.930000e+10
# 254     1.655000e+10                    3.206000e+10
# 255              NaN                    9.626000e+08
# 256              NaN                             NaN
# 257              NaN                             NaN
# 258     1.080000e+08                             NaN
# 259              NaN                    8.370000e+07
# 260     5.400000e+09                    2.827000e+09
# 261     5.353000e+09                    5.345000e+09
# 262     4.086000e+09                    1.122000e+10
#
#      Electricity - production(kWh)       Exports           GDP  ...  \
# 253                   8.970000e+10  3.584000e+10  1.452000e+11  ...
# 254                   3.448000e+10  2.372000e+10  2.272000e+11  ...
# 255                   1.035000e+09           NaN  2.500000e+09  ...
# 256                            NaN           NaN           NaN  ...
# 257                            NaN  2.500000e+05  6.000000e+07  ...
# 258                            NaN  2.050000e+08  1.800000e+09  ...
# 259                   9.000000e+07           NaN           NaN  ...
# 260                   3.040000e+09  4.468000e+09  1.625000e+10  ...
# 261                   8.167000e+09  1.548000e+09  9.409000e+09  ...
# 262                   8.839000e+09  1.409000e+09  2.437000e+10  ...
#
#      Oil - production(bbl/day)  Oil - proved reserves(bbl)  Population  \
# 253                  2600000.0                7.800000e+10  25375281.0
# 254                   359400.0                6.500000e+08  83535576.0
# 255                        0.0                         NaN    108708.0
# 256                        NaN                         NaN         NaN
# 257                        NaN                         NaN     16025.0
# 258                        NaN                         NaN   2385615.0
# 259                        0.0                         NaN    273008.0
# 260                   417500.0                4.000000e+09  20727063.0
# 261                        0.0                         NaN  11261795.0
# 262                        0.0                         NaN  12746990.0
#
#      Public debt(% of GDP)  Railways(km)  Reserves of foreign exchange & gold  \
# 253                   43.1         682.0                         2.575000e+10
# 254                   65.9        2600.0                         6.510000e+09
# 255                    NaN           NaN                                  NaN
# 256                    NaN           NaN                                  NaN
# 257                    NaN           NaN                                  NaN
# 258                    NaN           NaN                                  NaN
# 259                    NaN           NaN                                  NaN
# 260                   46.4           NaN                         5.300000e+09
# 261                  127.5        2173.0                         3.450000e+08
# 262                   52.3        3077.0                         5.700000e+07
#
#      Telephones - main lines in use  Telephones - mobile cellular  \
# 253                       2841800.0                     6463600.0
# 254                       4402000.0                     2742000.0
# 255                         69400.0                       41000.0
# 256                             NaN                           NaN
# 257                          1900.0                           0.0
# 258                        301600.0                      480000.0
# 259                             NaN                           0.0
# 260                        542200.0                      411100.0
# 261                         88400.0                      241000.0
# 262                        300900.0                      379100.0
#
#      Total fertility rate(children born/woman)  Unemployment rate(%)
# 253                                       2.26                  17.1
# 254                                       1.94                   1.9
# 255                                       2.19                   9.3
# 256                                        NaN                   NaN
# 257                                        NaN                   NaN
# 258                                       4.40                  27.2
# 259                                        NaN                   NaN
# 260                                       6.67                  35.0
# 261                                       5.47                  50.0
# 262                                       3.54                  70.0
#
# [10 rows x 45 columns]

# %%
df.shape
# Out:
# (263, 45)

# %%
df.columns
# Out:
# Index(['Country', 'Area(sq km)', 'Birth rate(births/1000 population)',
#        'Current account balance', 'Death rate(deaths/1000 population)',
#        'Debt - external', 'Electricity - consumption(kWh)',
#        'Electricity - production(kWh)', 'Exports', 'GDP', 'GDP - per capita',
#        'GDP - real growth rate(%)', 'HIV/AIDS - adult prevalence rate(%)',
#        'HIV/AIDS - deaths', 'HIV/AIDS - people living with HIV/AIDS',
#        'Highways(km)', 'Imports', 'Industrial production growth rate(%)',
#        'Infant mortality rate(deaths/1000 live births)',
#        'Inflation rate (consumer prices)(%)', 'Internet hosts',
#        'Internet users', 'Investment (gross fixed)(% of GDP)', 'Labor force',
#        'Life expectancy at birth(years)',
#        'Military expenditures - dollar figure',
#        'Military expenditures - percent of GDP(%)',
#        'Natural gas - consumption(cu m)', 'Natural gas - exports(cu m)',
#        'Natural gas - imports(cu m)', 'Natural gas - production(cu m)',
#        'Natural gas - proved reserves(cu m)', 'Oil - consumption(bbl/day)',
#        'Oil - exports(bbl/day)', 'Oil - imports(bbl/day)',
#        'Oil - production(bbl/day)', 'Oil - proved reserves(bbl)', 'Population',
#        'Public debt(% of GDP)', 'Railways(km)',
#        'Reserves of foreign exchange & gold', 'Telephones - main lines in use',
#        'Telephones - mobile cellular',
#        'Total fertility rate(children born/woman)', 'Unemployment rate(%)'],
#       dtype='object')

# %%
yemen=df[df["Country"]=="Yemen"]
yemen.head()
# Out:
#     Country  Area(sq km)  Birth rate(births/1000 population)  \
# 260   Yemen       527970                               43.07
#
#      Current account balance  Death rate(deaths/1000 population)  \
# 260              369900000.0                                8.53
#
#      Debt - external  Electricity - consumption(kWh)  \
# 260     5.400000e+09                    2.827000e+09
#
#      Electricity - production(kWh)       Exports           GDP  ...  \
# 260                   3.040000e+09  4.468000e+09  1.625000e+10  ...
#
#      Oil - production(bbl/day)  Oil - proved reserves(bbl)  Population  \
# 260                   417500.0                4.000000e+09  20727063.0
#
#      Public debt(% of GDP)  Railways(km)  Reserves of foreign exchange & gold  \
# 260                   46.4           NaN                         5.300000e+09
#
#      Telephones - main lines in use  Telephones - mobile cellular  \
# 260                        542200.0                      411100.0
#
#      Total fertility rate(children born/woman)  Unemployment rate(%)
# 260                                       6.67                  35.0
#
# [1 rows x 45 columns]

# %%
big_countries=df[(df["Area(sq km)"]>1000000) & (df["Population"]>100000000)]
big_countries=big_countries.loc[[big_countries['Population'].idxmax()],:]
big_countries
# Out:
#    Country  Area(sq km)  Birth rate(births/1000 population)  \
# 49   China      9596960                               13.14
#
#     Current account balance  Death rate(deaths/1000 population)  \
# 49             3.032000e+10                                6.94
#
#     Debt - external  Electricity - consumption(kWh)  \
# 49     2.333000e+11                    1.630000e+12
#
#     Electricity - production(kWh)       Exports           GDP  ...  \
# 49                   1.910000e+12  5.831000e+11  7.262000e+12  ...
#
#     Oil - production(bbl/day)  Oil - proved reserves(bbl)    Population  \
# 49                  3392000.0                1.774000e+10  1.306314e+09
#
#     Public debt(% of GDP)  Railways(km)  Reserves of foreign exchange & gold  \
# 49                   31.4       70058.0                         6.099000e+11
#
#     Telephones - main lines in use  Telephones - mobile cellular  \
# 49                     263000000.0                   269000000.0
#
#     Total fertility rate(children born/woman)  Unemployment rate(%)
# 49                                       1.72                   9.8
#
# [1 rows x 45 columns]

# %%
df.head()
# Out:
#           Country  Area(sq km)  Birth rate(births/1000 population)  \
# 0     Afghanistan       647500                               47.02
# 1        Akrotiri          123                                 NaN
# 2         Albania        28748                               15.08
# 3         Algeria      2381740                               17.13
# 4  American Samoa          199                               23.13
#
#    Current account balance  Death rate(deaths/1000 population)  \
# 0                      NaN                               20.75
# 1                      NaN                                 NaN
# 2            -5.040000e+08                                5.12
# 3             1.190000e+10                                4.60
# 4                      NaN                                3.33
#
#    Debt - external  Electricity - consumption(kWh)  \
# 0     8.000000e+09                    6.522000e+08
# 1              NaN                             NaN
# 2     1.410000e+09                    6.760000e+09
# 3     2.190000e+10                    2.361000e+10
# 4              NaN                    1.209000e+08
#
#    Electricity - production(kWh)       Exports           GDP  ...  \
# 0                   5.400000e+08  4.460000e+08  2.150000e+10  ...
# 1                            NaN           NaN           NaN  ...
# 2                   5.680000e+09  5.524000e+08  1.746000e+10  ...
# 3                   2.576000e+10  3.216000e+10  2.123000e+11  ...
# 4                   1.300000e+08  3.000000e+07  5.000000e+08  ...
#
#    Oil - production(bbl/day)  Oil - proved reserves(bbl)  Population  \
# 0                        0.0                0.000000e+00  29928987.0
# 1                        NaN                         NaN         NaN
# 2                     2000.0                1.855000e+08   3563112.0
# 3                  1200000.0                1.187000e+10  32531853.0
# 4                        0.0                         NaN     57881.0
#
#    Public debt(% of GDP)  Railways(km)  Reserves of foreign exchange & gold  \
# 0                    NaN           NaN                                  NaN
# 1                    NaN           NaN                                  NaN
# 2                    NaN         447.0                         1.206000e+09
# 3                   37.4        3973.0                         4.355000e+10
# 4                    NaN           NaN                                  NaN
#
#    Telephones - main lines in use  Telephones - mobile cellular  \
# 0                         33100.0                       15000.0
# 1                             NaN                           NaN
# 2                        255000.0                     1100000.0
# 3                       2199600.0                     1447310.0
# 4                         15000.0                        2377.0
#
#    Total fertility rate(children born/woman)  Unemployment rate(%)
# 0                                       6.75                   NaN
# 1                                        NaN                   NaN
# 2                                       2.04                  14.8
# 3                                       1.92                  25.4
# 4                                       3.25                   6.0
#
# [5 rows x 45 columns]

# %%
df.iloc[:,:5] # all rows with first 5 columns
df.iloc[:2, :10] #first 2 rows with first 10 columns
#last 5 rows with last 3 columns
df.iloc[-5:,-3:]
# Out:
#      Telephones - mobile cellular  Total fertility rate(children born/woman)  \
# 258                      480000.0                                       4.40
# 259                           0.0                                        NaN
# 260                      411100.0                                       6.67
# 261                      241000.0                                       5.47
# 262                      379100.0                                       3.54
#
#      Unemployment rate(%)
# 258                  27.2
# 259                   NaN
# 260                  35.0
# 261                  50.0
# 262                  70.0

# %%
new_df=df["Country"]
# Out:
#           Country
# 0     Afghanistan
# 1        Akrotiri
# 2         Albania
# 3         Algeria
# 4  American Samoa

# %%
# %% Data Filtering
# select columns
# select columns like df['Country]
type(df['Country'])  # returns Series
type(df[['Country']])  # returns DataFrame
# %%
# 1. find number of unique countries
len(pd.unique(df['Country']))
# %%
# select rows
# 2. get all countries with more than 1E6 people
df[df['Population']>1E6]
# %%
df['Population']>1E6
# %%

df[['Country', 'Population']].shape


# %%
(df['Population']>1E6).value_counts()
# %%
df[df['Population']>1E6]
# %% loc
df.loc[1:3, ['Country']]
# %% iloc
df.iloc[10:20, -4:]  # row 10 to 19, last four cols

# integer location
df.iloc[0,0]  # get the first 

# %%
df.iloc[1, :]  # 2nd row

# %%
df.iloc[:, -1]  # last column

# %% perform multiplication
df['Population'] /1000 * df['Birth rate(births/1000 population)']
# %% find the largest country in the world
df['Population'].sort_values(ascending=False)
# %%
df.loc[[49], :]  # manual approach
# %%
df.loc[[df['Population'].idxmax()], :]
# Out:
#    Country  Area(sq km)  Birth rate(births/1000 population)  \
# 49   China      9596960                               13.14
#
#     Current account balance  Death rate(deaths/1000 population)  \
# 49             3.032000e+10                                6.94
#
#     Debt - external  Electricity - consumption(kWh)  \
# 49     2.333000e+11                    1.630000e+12
#
#     Electricity - production(kWh)       Exports           GDP  ...  \
# 49                   1.910000e+12  5.831000e+11  7.262000e+12  ...
#
#     Oil - production(bbl/day)  Oil - proved reserves(bbl)    Population  \
# 49                  3392000.0                1.774000e+10  1.306314e+09
#
#     Public debt(% of GDP)  Railways(km)  Reserves of foreign exchange & gold  \
# 49                   31.4       70058.0                         6.099000e+11
#
#     Telephones - main lines in use  Telephones - mobile cellular  \
# 49                     263000000.0                   269000000.0
#
#     Total fertility rate(children born/woman)  Unemployment rate(%)
# 49                                       1.72                   9.8
#
# [1 rows x 45 columns]

# %% [markdown]
# ### Matplotlib
#
# Matplotlib is a comprehensive library for creating static, animated, and interactive visualizations in Python. [https://matplotlib.org/](https://matplotlib.org/)
#
# Matplot supports a number of visualizations for common data structures out of the box, for example:

# %%
import matplotlib.pyplot as plt

# drawing a bar diagram
plt.bar(language, percentage, color = 'r', label = 'File Data')
  
plt.xlabel('Programming languages', fontsize = 12)
plt.ylabel('popularity in %', fontsize = 12)

  
plt.title('Programming language popularity', fontsize = 20)
plt.xticks(rotation=45, ha="right")
plt.legend()
plt.show()

# %%
colors = ['yellow', 'b', 'green', 'cyan','red'] 
top5Percent = np.split(percentage,2)[0]
top5language = np.split(language,2)[0]
print("displaying pie chart of {}".format(top5language))

# plotting pie chart 
plt.pie(top5Percent, labels = top5language, colors = colors, startangle = 90,
        shadow = True, radius = 1.2) 
plt.show()
# Out:
# displaying pie chart of ['Python' 'Java' 'JavaScript' 'C#' 'PHP']

# %%
import pandas as pd
import numpy as np

#%%
df = pd.DataFrame({'language': ['R', 'Python', 'SQL', 'R', 'R', 'Python', 'Python'], 
                    'year': [2020, 2020, 2020, 2021, 2022, 2022, 2022],
                    'users': [1E6, 2E6, 0.5E6, 1.1E6, 1.2E6, 2.2E6, 2.4E6]})
df
# %%
df['users'].plot()
# %%
import matplotlib.pyplot as plt
plt.plot(df.loc[df['language']=='Python', 'users'])
plt.plot(df.loc[df['language']=='R', 'users'])
plt.plot(df.loc[df['language']=='SQL', 'users'])
plt.show()

# %%
#matplotlibintro
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

#%% 1D data -> automatic x labels
plt.plot([0, 2, 5, 6])
plt.title('my first plot')
plt.xlabel('automatically generated')
plt.show()


#%% 2D data
plt.plot([1, 3, 5, 7], [-10, 5, 25, 20])

#%% formatting
# color and line type: default b-, 
plt.plot([1, 3, 5, 7], [-10, 5, 25, 20], 'go')
plt.axis([0, 10, -15, 30])  # [xmin, xmax, ymin, ymax]

#%% multiple series
my_range = np.arange(0, 10, 1)
# plt.plot(my_range, my_range)
# plt.plot(my_range, my_range, 'b-')
plt.plot(my_range, my_range, 'b-o', my_range, my_range**0.5, 'g-s', my_range, my_range**1.5, 'r-^')


#%% Data Import
filename = "Diamonds.csv"
diamonds = pd.read_csv(filename)

# %% additional dimensions
diamonds['volume'] = diamonds['x'] * diamonds['y'] * diamonds['z']
plt.scatter(data=diamonds.iloc[:100, :], x='carat', y = 'depth', s='price', c='volume')
plt.xlabel('carat')
plt.ylabel('depth')
plt.colorbar(label='volume')
plt.show()

# %%
import pandas as pd

import matplotlib.pyplot as plt

programmingLanguages = pd.read_csv("programming-languages.txt", sep=';', header=None)
programmingLanguages.head(5).to_csv("programming-languages.csv", header=["language","percent"])

# %% [markdown]
# ### seaborn
#
# Seaborn is a Python data visualization library based on matplotlib. It provides a high-level interface for drawing attractive and informative statistical graphics. [https://seaborn.pydata.org/](https://seaborn.pydata.org/)

# %%
#seaborn
import seaborn as sns
import pandas as pd

# %%
filename = "Diamonds.csv"
diamonds = pd.read_csv(filename)
diamonds['volume'] = diamonds['x'] * diamonds['y'] * diamonds['z']
#%%
sns.set_theme(style='darkgrid')
s= sns.relplot(data=diamonds.iloc[1500:2000, :], x='carat', y = 'price', size='depth', hue='cut', style='clarity')
s.set(ylim = (3000, 3150))

# %% [markdown]
# ## Data Manipulation

# %%
### Data Grouping

# %%
import pandas as pd
import numpy as np

#%%
df = pd.DataFrame({'language': ['R', 'Python', 'SQL', 'R', 'R', 'Python', 'Python'], 
                    'year': [2020, 2020, 2020, 2021, 2022, 2022, 2022],
                    'users': [1E6, 2E6, 0.5E6, 1.1E6, 1.2E6, 2.2E6, 2.4E6]})
df

# %% understand grouping
for name, group in df.groupby('language'):
    mean_val = group['users'].mean()
    print(f"{name}: {mean_val}")

# %% group on a column and average over all other cols
# df.groupby('language').mean()
df.groupby('language').agg(np.mean)
# %% group on a column, average over a specific column
df.groupby('language')['users'].mean()
# %% group by multiple columns
df.groupby(['language', 'year'])['users'].mean()
# %% several aggregation functions
df.groupby('language').agg({'users': ['mean', 'min', 'max', 'sum']})

# %%
df.groupby('language').agg([np.mean, np.sum])

# %%
import pandas as pd
data = {'group_col': ['A', 'B', 'C', 'A', 'B', 'A'],
                   'value_col': [0, -2, 5, 2, 2, 4]}
df = pd.DataFrame(data)
df


#%%

# %%
for name, group in df.groupby('group_col'):
    group_values = group['value_col'].tolist()
    print(f"{name}: {group_values}")
# %%
df.groupby('group_col').agg({'value_col': [np.mean, np.sum]})

# %%
df.groupby('group_col').size()

# %%
#Exercise
#%% packages

#%% 0. add required packages at the top of this script

# %% 1. import dataset from subfolder "data"

# %% 2. how many rows and columns does it have

# %% 3. which columns does it have?

# %% 4. There is a column named 'Unnamed: 0'. Please delete it.

# %% 5. which levels does column cut have?

# %% 6. create a barplot for diamonds and their cut's
#%% 7. save the graph as png-file

# %% 8. find out what the median price per cut is.

# %% 9. Create two filtered dataframes which only have the cut 'Ideal' and 'Premium'. Store it in the dataframes 'df_cut_ideal' and 'df_cut_premium'

# %% 10. stack the dataframes together to get a combined version df_cut_ideal_premium

# %% 11. save the dataframe to a csv file in subfolder data: 'df_cut_ideal_premium.csv'

# %%
#join
import pandas as pd
import numpy as np

#%% prepare dataframes
# use main characters of animated films

minions = pd.DataFrame({
    'student': ['Stuart', 'Bob', 'Kevin', 'Gru'],
    'art': [4,2,1, 2]
    
})
print(f"minions:\n {minions}")

despicable_me = pd.DataFrame({
    'student': ['Agnes', 'Margo', 'Edith', 'Gru'],
    'sport': [1,2,2, 3]
    
})
print(f"despicable me:\n {despicable_me}")






frozen = pd.DataFrame({
    'student': ['Anna', 'Elsa', 'Olaf'],
    'art': [4,2,1]
})
print(f"frozen:\n {frozen}")

simpsons = pd.DataFrame({
    'student': ['Bart', 'Lisa'],
    'math': [5,1],
    'sport': [1,5]
    
})
print(f"simpsons:\n {simpsons}")

#%% left join
# how: left, right, inner, outer
# minions.merge(right=despicable_me, how='right', on='student', indicator=True)
minions.merge(right=despicable_me, how='right', left_on='student', right_on='student', indicator=True)

#%% join via index
despicable_me_index = despicable_me.copy()
despicable_me_index.index = despicable_me_index['student']
despicable_me_index.drop(columns=['student'], axis=1, inplace=True)
print(f"despicable me index:\n {despicable_me_index}")

minions.merge(right=despicable_me_index, how='right', left_on='student', right_index=True, indicator=True).reset_index(drop=True)



# %% append rows
minions.append(frozen)
# %% alternatively
pd.concat([minions, frozen])
# %% append columns
pd.concat([minions, simpsons])
